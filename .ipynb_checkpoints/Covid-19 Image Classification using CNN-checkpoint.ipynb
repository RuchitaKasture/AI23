# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, img_to_array
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten

import warnings
warnings.filterwarnings("ignore")

# %%
train_dir = r"D:\Data Science Program\AI\Covid19-dataset\train"
test_dir = r"D:\Data Science Program\AI\Covid19-dataset\test"

# %%
width = 500
height = 500

batch = 32

# %%
train_dataset = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=20,
    height_shift_range=0.2,
    width_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
train_img = train_dataset.flow_from_directory(
    train_dir,
    target_size=(width,height),
    batch_size=batch,
    class_mode="categorical"
)
# Out:
# Found 251 images belonging to 3 classes.

# %%
test_dataset = ImageDataGenerator(rescale=1/255.0)

# %%
test_img = test_dataset.flow_from_directory(
    test_dir,
    target_size=(width,height),
    batch_size=batch,
    class_mode="categorical"
)
# Out:
# Found 66 images belonging to 3 classes.

# %%
train_img.class_indices
# Out:
# {'Covid': 0, 'Normal': 1, 'Viral Pneumonia': 2}

# %%
classes = {val:key for key,val in train_img.class_indices.items()}

# %%
classes
# Out:
# {0: 'Covid', 1: 'Normal', 2: 'Viral Pneumonia'}

# %%
model = Sequential([
    Conv2D(64, (3,3), strides=(1,1), padding="valid", input_shape=(width, height,3), activation="relu"),
    MaxPool2D(2,2),
    Conv2D(128, (3,3), strides=(1,1), padding="valid", activation="relu"),
    MaxPool2D(2,2),
    Conv2D(256, (3,3), strides=(1,1), padding="valid", activation="relu"),
    MaxPool2D(2,2),
    Flatten(),
    Dense(128, activation="relu"),
    Dense(256, activation="relu"),
    Dense(128, activation="relu"),
    Dense(3, activation="softmax"),

])

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_img, epochs=25, batch_size= batch, validation_data=test_img)
# Out:
# Epoch 1/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 255s 31s/step - accuracy: 0.3094 - loss: 3.4283 - val_accuracy: 0.5000 - val_loss: 1.0822
# Epoch 2/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 172s 20s/step - accuracy: 0.6303 - loss: 0.8840 - val_accuracy: 0.6061 - val_loss: 1.5306
# Epoch 3/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 142s 18s/step - accuracy: 0.6210 - loss: 1.0202 - val_accuracy: 0.3939 - val_loss: 1.1989
# Epoch 4/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - accuracy: 0.6378 - loss: 0.7696 - val_accuracy: 0.4848 - val_loss: 1.3777
# Epoch 5/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - accuracy: 0.7487 - loss: 0.5868 - val_accuracy: 0.6515 - val_loss: 1.2452
# Epoch 6/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - accuracy: 0.8026 - loss: 0.4476 - val_accuracy: 0.5909 - val_loss: 1.3349
# Epoch 7/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - accuracy: 0.7327 - loss: 0.7369 - val_accuracy: 0.4848 - val_loss: 0.8074
# Epoch 8/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 202s 18s/step - accuracy: 0.7900 - loss: 0.5660 - val_accuracy: 0.6364 - val_loss: 0.8063
# Epoch 9/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8487s 1209s/step - accuracy: 0.8567 - loss: 0.3991 - val_accuracy: 0.6515 - val_loss: 0.8276
# Epoch 10/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 249s 31s/step - accuracy: 0.8240 - loss: 0.4395 - val_accuracy: 0.5152 - val_loss: 1.3922
# Epoch 11/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 242s 30s/step - accuracy: 0.7307 - loss: 0.6756 - val_accuracy: 0.7576 - val_loss: 0.6775
# Epoch 12/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 259s 32s/step - accuracy: 0.7706 - loss: 0.5988 - val_accuracy: 0.6970 - val_loss: 0.8012
# Epoch 13/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 630s 85s/step - accuracy: 0.7690 - loss: 0.5349 - val_accuracy: 0.7121 - val_loss: 0.7766
# Epoch 14/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 141s 17s/step - accuracy: 0.8096 - loss: 0.5217 - val_accuracy: 0.7879 - val_loss: 0.6834
# Epoch 15/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - accuracy: 0.8299 - loss: 0.4311 - val_accuracy: 0.8030 - val_loss: 0.5604
# Epoch 16/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 149s 18s/step - accuracy: 0.8368 - loss: 0.4992 - val_accuracy: 0.6818 - val_loss: 0.6445
# Epoch 17/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 198s 18s/step - accuracy: 0.8614 - loss: 0.3553 - val_accuracy: 0.8030 - val_loss: 0.6275
# Epoch 18/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 18s/step - accuracy: 0.8448 - loss: 0.3522 - val_accuracy: 0.7121 - val_loss: 0.7878
# Epoch 19/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - accuracy: 0.8535 - loss: 0.4166 - val_accuracy: 0.7727 - val_loss: 0.6881
# Epoch 20/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 143s 18s/step - accuracy: 0.8455 - loss: 0.3501 - val_accuracy: 0.7273 - val_loss: 0.6778
# Epoch 21/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 146s 18s/step - accuracy: 0.8458 - loss: 0.4143 - val_accuracy: 0.7424 - val_loss: 0.6411
# Epoch 22/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - accuracy: 0.9019 - loss: 0.3320 - val_accuracy: 0.7121 - val_loss: 0.7265
# Epoch 23/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - accuracy: 0.8573 - loss: 0.3590 - val_accuracy: 0.7879 - val_loss: 0.5193
# Epoch 24/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 144s 18s/step - accuracy: 0.8809 - loss: 0.3707 - val_accuracy: 0.7879 - val_loss: 0.6020
# Epoch 25/25
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 145s 18s/step - accuracy: 0.9030 - loss: 0.2693 - val_accuracy: 0.6818 - val_loss: 0.8542

# %%
plt.figure(figsize=(12,4))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"],label="validation Loss")
plt.title("Loss visulization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(model.history.history["accuracy"], label="Training Accuracy")
plt.plot(model.history.history["val_loss"],label="validation Accuracy")
plt.title("Accuracy visulization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()
